# %%
string = "0123456789"

print(string[:3] + string[7:])
# Out:
# 012789

# %%
string = '''Chief Complaint:
   24 Hour Events:
 NON-INVASIVE VENTILATION - START 2167-3-4 08:55 AM
 NON-INVASIVE VENTILATION - STOP 2167-3-4 11:30 AM
 PICC LINE - START 2167-3-4 12:00 PM
 CHEST PAIN - At 2167-3-4 05:13 PM
   Flash Pulmonary edema again yest PM, responded to lasix, CPAP
   Persistently agigated and disoriented despite resolution of hypoxia,
   given IV haldol 0.5mg x 2 with good effect
   Able to transition to high flow neb with stable O2 sats
   THIS AM:
   says breathing is fine, not labored, but still appears in mild
   respiratory distress
   She is A+O x 3
   Allergies:
   Morphine
   Rash;
   Betalactams
   Neutropenia;
   Iodine; Iodine Containing
   Hives;
   Last dose of Antibiotics:
   Vancomycin - 2167-3-4 08:00 PM
   Aztreonam - 2167-3-5 06:11 AM
   Infusions:
   Other ICU medications:
   Other medications:
   Changes to medical and family history:
   Review of systems is unchanged from admission except as noted below
   Review of systems:
   Flowsheet Data as of  2167-3-5 08:00 AM
   Vital signs
   Hemodynamic monitoring
   Fluid balance
                                                                  24 hours
                                                               Since 12 AM
   Tmax: 38.2
C (100.7
   Tcurrent: 36.9
C (98.5
   HR: 80 (67 - 124) bpm
   BP: 116/43(62) {94/40(53) - 149/80(98)} mmHg
   RR: 20 (17 - 39) insp/min
   SpO2: 100%
   Heart rhythm: AF (Atrial Fibrillation)
   Wgt (current): 87.7 kg (admission): 87.7 kg
             Total In:
                                                                    492 mL
                                                                    229 mL
   PO:
                                                                     50 mL
                                                                     50 mL
   TF:
   IVF:
                                                                    442 mL
                                                                    179 mL
   Blood products:
   Total out:
                                                                  1,110 mL
                                                                    490 mL
   Urine:
                                                                  1,110 mL
                                                                    490 mL
   NG:
   Stool:
   Drains:
   Balance:
                                                                   -618 mL
                                                                   -261 mL
   Respiratory support
   O2 Delivery Device: Nasal cannula, High flow neb
   Ventilator mode: Standby
   Vt (Spontaneous): 550 (526 - 550) mL
   PS : 10 cmH2O
   RR (Spontaneous): 31
   PEEP: 5 cmH2O
   FiO2: 100%
   SpO2: 100%
   ABG: 7.45/40/143/25/4
   Ve: 15.2 L/min
   PaO2 / FiO2: 143
   Physical Examination
   General Appearance: Overweight / Obese, Anxious
   Eyes / Conjunctiva: PERRL
   Peripheral Vascular: (Right radial pulse: Not assessed), (Left radial
   pulse: Not assessed), (Right DP pulse: Not assessed), (Left DP pulse:
   Not assessed)
   Respiratory / Chest: (Expansion: Paradoxical), (Breath Sounds: Crackles
   : inspiratory b/l '''

print(len(string))
# Out:
# 3159

# %%
string = "TESDJHIUFHAIOFJA DFSAJHNDIKOSADJMASKLPD FHNAINSFKSD."
print(string.isupper())
# Out:
# True

# %%
string = '''\[\*\*.*?\*\*\]|<|>|"|''' + "'"
print(string)
# Out:
# \[\*\*.*?\*\*\]|<|>|"|'

# %%
for i in range(0, 1000000):
    if i == 4:
        exit()

# %%
import random

def generate(length):
    minmax = [0, 0]
    minmax[0] = 1 * (10**(length-1))
    minmax[1] = 1 * (10**length)
    
    return random.randint(minmax[0], minmax[1])

generate(100000)
# Out:
# ...

# %%
print("\ntest")
# Out:
# test

# %%
import re
import pandas as pd

data = pd.read_csv('./data/deidentified_notes_mimic').to_numpy()

for text in data:
    if text == data[0]:
        print(text)
        break
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-52e3ef335397> in <module>
#       2 import pandas as pd
#       3
# ----> 4 data = pd.read_csv('./data/deidentified_notes_mimic').to_numpy()
#       5
#       6 for text in data:
#
# ...

# %%
def test():
    """bleh
    
    inputs: bleh
    
    outputs: nom
    
    blehs nom and returns nom
    
    """
    
    return "nom"

# %%
test().__doc__
# Out:
# "str(object='') -> str\nstr(bytes_or_buffer[, encoding[, errors]]) -> str\n\nCreate a new string object from the given object. If encoding or\nerrors is specified, then the object must expose a data buffer\nthat will be decoded using the given encoding and error handler.\nOtherwise, returns the result of object.__str__() (if defined)\nor repr(object).\nencoding defaults to sys.getdefaultencoding().\nerrors defaults to 'strict'."
